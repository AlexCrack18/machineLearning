# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexCrack18/Machine-Learnng/blob/main/Auto_excercise_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto = pd.read_csv("Auto.csv")

# %%
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
auto = auto.set_index("name")

# %%
auto
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ...                         ...        ...           ...        ...     ...
# ford mustang gl            27.0          4         140.0         86    2790
# vw pickup                  44.0          4          97.0         52    2130
# dodge rampage              32.0          4         135.0         84    2295
# ford ranger                28.0          4         120.0         79    2625
# chevy s-10                 31.0          4         119.0         82    2720
#
# ...

# %%
auto = auto.dropna()

# %%
auto
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ...                         ...        ...           ...        ...     ...
# ford mustang gl            27.0          4         140.0         86    2790
# vw pickup                  44.0          4          97.0         52    2130
# dodge rampage              32.0          4         135.0         84    2295
# ford ranger                28.0          4         120.0         79    2625
# chevy s-10                 31.0          4         119.0         82    2720
#
# ...

# %%
range = auto.select_dtypes(include="number").max() - auto.select_dtypes(include="number").min()
range
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %%
mean_auto = auto.select_dtypes("number").mean()
stdev_auto = auto.select_dtypes("number").std()
mean_auto
# Out:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64

# %%
stdev_auto
# Out:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %%
sub_auto = auto.drop(auto.index[10:86])
sub_auto
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
# ford torino         17.0          8         302.0        140    3449
# amc ambassador dpl  15.0          8         390.0        190    3850
# ...                  ...        ...           ...        ...     ...
# ford mustang gl     27.0          4         140.0         86    2790
# vw pickup           44.0          4          97.0         52    2130
# dodge rampage       32.0          4         135.0         84    2295
# ford ranger         28.0          4         120.0         79    2625
# chevy s-10          31.0          4         119.0         82    2720
#
#                     acceleration  year  origin
# name
# buick skylark 320           11.5    70       1
# ...

# %%
auto
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ...                         ...        ...           ...        ...     ...
# ford mustang gl            27.0          4         140.0         86    2790
# vw pickup                  44.0          4          97.0         52    2130
# dodge rampage              32.0          4         135.0         84    2295
# ford ranger                28.0          4         120.0         79    2625
# chevy s-10                 31.0          4         119.0         82    2720
#
# ...

# %%
auto = auto.dropna()
auto
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ...                         ...        ...           ...        ...     ...
# ford mustang gl            27.0          4         140.0         86    2790
# vw pickup                  44.0          4          97.0         52    2130
# dodge rampage              32.0          4         135.0         84    2295
# ford ranger                28.0          4         120.0         79    2625
# chevy s-10                 31.0          4         119.0         82    2720
#
# ...

# %%
print(auto.shape)  # Should be (397, X)
print(len(auto.index[10:86]))  # Should be 76
# Out:
# (397, 8)
# 76

# %%
print(auto.shape[0] - len(auto.index[10:86]))  # Should be 321
# Out:
# 321

# %%
sub_auto = sub_auto[[]].iloc[0:0]

# %%
sub_auto = auto.drop(auto.index[10:86])
print(sub_auto.shape)
# Out:
# (280, 8)

# %%
print(auto.dropna().shape)
# Out:
# (397, 8)

# %%
auto_clean = auto.dropna()
print(auto_clean.shape)
# Out:
# (397, 8)

# %%
sub_auto
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
# ford torino         17.0          8         302.0        140    3449
# amc ambassador dpl  15.0          8         390.0        190    3850
# ...                  ...        ...           ...        ...     ...
# ford mustang gl     27.0          4         140.0         86    2790
# vw pickup           44.0          4          97.0         52    2130
# dodge rampage       32.0          4         135.0         84    2295
# ford ranger         28.0          4         120.0         79    2625
# chevy s-10          31.0          4         119.0         82    2720
#
#                     acceleration  year  origin
# name
# buick skylark 320           11.5    70       1
# ...

# %%
sns.pairplot(auto.select_dtypes("number"))
plt.suptitle("Pairwise Scatterplots of Numeric Predictors", y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(auto.select_dtypes("number").corr(), annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Matrix of Numeric Predictors")
plt.show()
